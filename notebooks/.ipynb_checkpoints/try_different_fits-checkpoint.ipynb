# %% [markdown]
# Try different sigma dependencies \& determine the best one based off of $\Delta \chi^2$

# %%
from escripts import eMCMC
from escripts import eplots
Plotting = eplots.Plotting()
import importlib
import time

# %%
importlib.reload(eMCMC)
# Out:
# <module 'escripts.eMCMC' from '/Users/eb35267/Desktop/code/home/escripts/eMCMC.py'>

# %%
file_names = ['/Users/eb35267/Desktop/code/home/data/Bouwens2021_fixed.txt']
data_labels = ['Bouwens+21', 'Donnan+24', 'McLeod+24']

# %%
eMCMC.get_default_dict()
# Out:
#             fit value start lower upper                             label
# alpha      True   0.6   0.6     0     4                          $\alpha$
# dalphadz   True     0  0.01  -0.5   0.5                      $d\alpha/dz$
# beta       True  -0.5  -0.5    -1     0                           $\beta$
# dbetadz    True     0  0.01  -0.5   0.5                       $d\beta/dz$
# logMc      True    12    12     9    16                       $\log(M_c)$
# dlogMcdz   True     0  0.01  -0.5   0.5                   $d\log(M_c)/dz$
# loge       True  -0.5    -1    -1     1                $\log(\epsilon_0)$
# dlogedz    True     0  0.01  -0.5   0.5            $d\log(\epsilon_0)/dz$
# sig        True     0   0.5     0     6            $\sigma_{\rm{UV}, 10}$
# dsigdz     True     0  0.01  -0.5   0.5            $d\sigma_{\rm{UV}}/dz$
# dsigdlogM  True     0  0.01  -0.5   0.5  $d\sigma_{\rm{UV}}/d\log(M_{h})$

# %%
param_const = eMCMC.build_param_data({'dsigdlogM': {'fit':False}, 'dsigdz': {'fit':False}})

# %%
UVLF_const = eMCMC.UVLF(file_names, data_labels, param_const)

# %%
ICs_const = UVLF_const.generate_ICs()
# Out:
# /Users/eb35267/miniconda3/envs/research/lib/python3.12/site-packages/zeus21/UVLFs.py:33: RuntimeWarning: divide by zero encountered in log10
#   MUVtab = 51.63 - 2.5 * np.log10(LUVtab) #AB magnitude
# /Users/eb35267/miniconda3/envs/research/lib/python3.12/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]

# %%
# Run MCMC
Nsteps=2000
UVLF_const.sampler.run_mcmc(ICs_const, Nsteps)
# Out:
# State([[ 7.01148488e-01  2.04948207e-02 -5.80221590e-01  3.57729906e-03
#    1.20191172e+01  7.76806757e-02 -9.10604044e-01 -2.48040863e-02
#    4.03514347e-01]
#  [ 8.02780370e-01  3.81251194e-02 -1.87127115e-01  8.41917885e-02
#    1.16853146e+01 -1.79177733e-02 -9.76927361e-01 -5.30837916e-02
#    3.24363857e-01]
#  [ 6.28292444e-01  1.65725706e-02 -8.78710411e-02  2.86469775e-01
#    1.19800570e+01  4.86700667e-03 -9.76579996e-01 -3.67753295e-02
#    4.49446155e-01]
#  [ 5.88625826e-01 -1.13848607e-02 -8.94317061e-01 -1.34336716e-01
#    1.24488818e+01  1.89019624e-01 -8.29593141e-01  8.32607780e-03
#    4.13829393e-01]
#  [ 6.84077079e-01  1.50398214e-03 -1.13425319e-01  2.08203609e-01
#    1.18811312e+01  6.27469445e-03 -9.71460160e-01 -5.84070156e-02
#    3.65544039e-01]
#  [ 6.80435900e-01  1.52199567e-02 -1.39668621e-01  1.95981665e-01
#        4125101589, 3477838506, 4230094228, 3300150842, 3526474412,
#        4268982779, 1079016313, 3001847919,  897937584, 1347192004,
#         386343118, 3140196287, 3659645624, 1517076497, 1002003204,
#        2264922340, 3454453767, 3549652831, 1285497994, 2442432121,
#        2495216917, 3386643892, 2616750651,  523841799,  804984239,
#        1825515996, 3688997064, 2571133040, 2300601997, 3754448524,
#        1927529165, 3340644249, 3301428417,  192084250, 3624392021,
#        2702376305, 4120644700, 1068209700,  517998659,  711464654,
#        3899841569, 3572114803, 4117911142, 2679159561,  537898460,
#        2696865058, 3356762528, 1791008228, 4183390462, 1775409845,
#        2344337215,  200960509, 1948442449, 1882879245,  249204661,
#        3923658453, 4002633093, 1711286516, 1868529565, 2865843516,
#        1897412138,  219194005, 1417466236, 1206823761, 3162179064,
#          61294162,  318475169, 4276743063, 2183277034, 3262594338,
#         354689100, 1793595934, 2721113184, 3490944702, 3993912405,
#        1254823031, 2995286976, 2710336989, 1938142126,  882143044,
#        2116474299, 1609847953, 2454305909,  761521869, 3201642666,
#         411059375, 3283796953, 2849968346, 3943657168, 1726085835,
#        4117931045, 1393330261, 3698026619, 2739566009,  631723335,
#        3973241709, 3467646226,  941084985, 1110743469, 1732564109,
#        3990637933,  776863357,  982159392, 3484768778, 1426955058,
#        1497433664, 1081635579, 2931171158, 3504446011, 2514943179,
#         879609265, 3308234413, 2209532421, 3456469647, 2397595089,
#        1760843236, 2170072680, 1829292154, 3446975347,  234210341,
#        3428305198, 2983538397, 2911680678, 4219909444, 2191696035,
#        3318656730,  606973881, 1926035929, 2668012574, 3621606265,
#         472055632, 1106526909, 2723816108, 1624097841], dtype=uint32), 252, 0, 0.0))

# %%
# Get flat sample from the MCMC
samples_const = UVLF_const.sampler.get_chain(discard = 400, flat=True)

# %%
corner_const = Plotting.plot_corner(samples_const, UVLF_const, title = r'constant $\sigma_{\rm{UV}}$')

# %%
#corner_const.savefig('/Users/eb35267/Desktop/code/figures/sigma_function/posterior_const_sig.png', bbox_inches='tight')

# %%
best_fit_const, labels = UVLF_const.get_best_fit(samples_const)

# %%
print(best_fit_const)
# Out:
# [0.67, 0.01, -0.36, 0.12, 12.02, 0.05, -0.94, -0.03, 0.39, 0, 0]

# %%
param_M = eMCMC.build_param_data({'dsigdz': {'fit': False}})

# %%
UVLF_M = eMCMC.UVLF(file_names, data_labels, param_M)

# %%
ICs_M = UVLF_M.generate_ICs()
# Out:
# /Users/eb35267/miniconda3/envs/research/lib/python3.12/site-packages/zeus21/UVLFs.py:33: RuntimeWarning: divide by zero encountered in log10
#   MUVtab = 51.63 - 2.5 * np.log10(LUVtab) #AB magnitude
# /Users/eb35267/miniconda3/envs/research/lib/python3.12/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]

# %%
# Run MCMC
UVLF_M.sampler.run_mcmc(ICs_M, Nsteps) 
# Get flat sample from the MCMC
samples_M = UVLF_M.sampler.get_chain(discard = 400, flat=True)

# %%
best_fit_M, _ = UVLF_M.get_best_fit(samples_M)

# %%
corner_M = Plotting.plot_corner(samples_M, UVLF_M, title = r'$\sigma_{\rm{UV}}(M_h)$')

# %%
#corner_M.savefig('/Users/eb35267/Desktop/code/figures/sigma_function/weird_posterior_sig_m.png', bbox_inches='tight')

# %%
params_z = eMCMC.build_param_data({'dsigdlogM': {'fit': False}})

# %%
UVLF_z = eMCMC.UVLF(file_names, data_labels, params_z)

# %%
ICs_z = UVLF_z.generate_ICs()
# Out:
# /Users/eb35267/miniconda3/envs/research/lib/python3.12/site-packages/zeus21/UVLFs.py:33: RuntimeWarning: divide by zero encountered in log10
#   MUVtab = 51.63 - 2.5 * np.log10(LUVtab) #AB magnitude
# /Users/eb35267/miniconda3/envs/research/lib/python3.12/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]

# %%
# Run MCMC
UVLF_z.sampler.run_mcmc(ICs_z, Nsteps) 
# Get flat sample from the MCMC
samples_z = UVLF_z.sampler.get_chain(discard = 400, flat=True)

# %%
best_fit_z, _ = UVLF_z.get_best_fit(samples_z)

# %%
corner_z = Plotting.plot_corner(samples_z, UVLF_z, title = r'$\sigma_{\rm{UV}}(z)$')

# %%
#corner_z.savefig('/Users/eb35267/Desktop/code/figures/sigma_function/posterior_sig_z.png', bbox_inches = 'tight')

# %%
print(best_fit_z)
# Out:
# [0.64, 0.01, -0.4, 0.15, 12.04, 0.05, -0.95, -0.03, 0.34, -0.04, 0]

# %%
params_all = eMCMC.build_param_data({})

# %%
UVLF_all = eMCMC.UVLF(file_names, data_labels, params_all)

# %%
ICs_all = UVLF_all.generate_ICs()
# Out:
# /Users/eb35267/miniconda3/envs/research/lib/python3.12/site-packages/zeus21/UVLFs.py:33: RuntimeWarning: divide by zero encountered in log10
#   MUVtab = 51.63 - 2.5 * np.log10(LUVtab) #AB magnitude
# /Users/eb35267/miniconda3/envs/research/lib/python3.12/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]

# %%
UVLF_all.sampler.run_mcmc(ICs_all, Nsteps)
samples_all = UVLF_all.sampler.get_chain(discard=400, flat=True)

# %%
best_fit_all, _ = UVLF_all.get_best_fit(samples_all)

# %%
corner_all = Plotting.plot_corner(samples_all, UVLF_all, title = r'$\sigma_{\rm{UV}}(M_h, z)$')

# %%
#corner_all.savefig('/Users/eb35267/Desktop/code/figures/sigma_function/weird_posterior_sig_mz.png', bbox_inches = 'tight')

# %%
comparison = Plotting.compare_fits(file_names, data_labels, [best_fit_const, best_fit_M, best_fit_z, best_fit_all], 
        fit_labels = [r'constant $\sigma_{\rm{UV}}$', r'$\sigma_{\rm{UV}}(M_h)$', r'$\sigma_{\rm{UV}}(z)$', r'$\sigma_{\rm{UV}}(M_h, z)$'],
                                  title = 'Fit comparison, just HST data')
# Out:
# /Users/eb35267/miniconda3/envs/research/lib/python3.12/site-packages/zeus21/UVLFs.py:33: RuntimeWarning: divide by zero encountered in log10
#   MUVtab = 51.63 - 2.5 * np.log10(LUVtab) #AB magnitude

# %%
#comparison.savefig('/Users/eb35267/Desktop/code/figures/sigma_function/diff_sigma_func_just_HST.png', bbox_inches='tight')

# %%
#comparison.savefig('/Users/eb35267/Desktop/code/figures/sigma_function/diff_sigma_func_compare.png', bbox_inches='tight')

# %%
# This is just to replace 0s with '-' to emphasize that the parameter wasn't fit. I'm sure there's a smarter way I could do this than manually lol
best_fit_const_t = [0.64, -0.07, -0.58, -0.06, 12.19, 0.23, -0.89, -0.0, 0.37, '-', '-']
best_fit_M_t = [0.63, -0.06, -0.5, -0.06, 12.45, 0.28, -0.85, 0.02, 0.75, '-', -0.2]
best_fit_z_t = [0.58, -0.06, -0.61, -0.05, 12.33, 0.22, -0.93, -0.02, 0.5, 0.04, '-']

# %%
table = eMCMC.make_table([best_fit_const_t, best_fit_M_t, best_fit_z_t, best_fit_all], labels, 
        fit_labels = [r'constant $\sigma_{\rm{UV}}$', r'$\sigma_{\rm{UV}}(M_h)$', r'$\sigma_{\rm{UV}}(z)$', r'$\sigma_{\rm{UV}}(M_h, z)$'])

# %%
table
# Out:
#                                  constant $\sigma_{\rm{UV}}$  \
# $\alpha$                                                0.64
# $d\alpha/dz$                                           -0.07
# $\beta$                                                -0.58
# $d\beta/dz$                                            -0.06
# $\log(M_c)$                                            12.19
# $d\log(M_c)/dz$                                         0.23
# $\log(\epsilon_0)$                                     -0.89
# $d\log(\epsilon_0)/dz$                                  -0.0
# $\sigma_{\rm{UV}, 10}$                                  0.37
# $d\sigma_{\rm{UV}}/dz$                                     -
# $d\sigma_{\rm{UV}}/d\log(M_{h})$                           -
#
#                                  $\sigma_{\rm{UV}}(M_h)$  \
# $\alpha$                                            0.63
# $d\alpha/dz$                                       -0.06
# $\beta$                                             -0.5
# $d\beta/dz$                                        -0.06
# $\log(M_c)$                                        12.45
# $d\log(M_c)/dz$                                     0.28
# $\log(\epsilon_0)$                                 -0.85
# $d\log(\epsilon_0)/dz$                              0.02
# $\sigma_{\rm{UV}, 10}$                              0.75
# $d\sigma_{\rm{UV}}/dz$                                 -
# $d\sigma_{\rm{UV}}/d\log(M_{h})$                    -0.2
#
#                                  $\sigma_{\rm{UV}}(z)$  \
# $\alpha$                                          0.58
# $d\alpha/dz$                                     -0.06
# $\beta$                                          -0.61
# $d\beta/dz$                                      -0.05
# $\log(M_c)$                                      12.33
# $d\log(M_c)/dz$                                   0.22
# $\log(\epsilon_0)$                               -0.93
# $d\log(\epsilon_0)/dz$                           -0.02
# $\sigma_{\rm{UV}, 10}$                             0.5
# $d\sigma_{\rm{UV}}/dz$                            0.04
# $d\sigma_{\rm{UV}}/d\log(M_{h})$                     -
#
#                                  $\sigma_{\rm{UV}}(M_h, z)$
# $\alpha$                                               0.62
# $d\alpha/dz$                                          -0.05
# $\beta$                                               -0.46
# $d\beta/dz$                                           -0.02
# $\log(M_c)$                                           12.38
# $d\log(M_c)/dz$                                        0.23
# $\log(\epsilon_0)$                                    -0.91
# $d\log(\epsilon_0)/dz$                                -0.01
# $\sigma_{\rm{UV}, 10}$                                 0.78
# $d\sigma_{\rm{UV}}/dz$                                 0.03
# $d\sigma_{\rm{UV}}/d\log(M_{h})$                      -0.18
