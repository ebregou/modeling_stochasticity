# %% [markdown]
# Attempting to test whether emcee chains are converged

# %%
from escripts import eMCMC
from escripts import eplots
from escripts import edata
import importlib
import emcee
import pandas as pd

# %%
file_names = ['/Users/eb35267/Desktop/code/home/data/Bouwens2021_fixed.txt', 
              '/Users/eb35267/Desktop/code/home/data/Donnan24_GAL.txt',
             '/Users/eb35267/Desktop/code/home/data/Mcleod_24.txt']
data_labels = ['Bouwens+21', 'Donnan+24', 'McLeod+24']
sorted_data = edata.get_sorted(file_names, data_labels)

# %%
params = eMCMC.build_param_data({})

# %%
importlib.reload(eMCMC)
# Out:
# <module 'escripts.eMCMC' from '/Users/eb35267/Desktop/code/home/escripts/eMCMC.py'>

# %%
my_UVLF = eMCMC.UVLF(sorted_data, params,)

# %%
my_UVLF.run_MCMC(Nsteps = 100000)
# Out:
# /Users/eb35267/Desktop/code/home/escripts/eMCMC.py:152: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   insert_vals = self.param_data['value'][self.notfit]
# /Users/eb35267/Desktop/code/home/escripts/eMCMC.py:153: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   else:
# /Users/eb35267/miniconda3/envs/research/lib/python3.12/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]

# %%
samples = my_UVLF.sampler.get_chain(discard=400)

# %%
times = emcee.autocorr.integrated_time(samples, has_walkers=True)

# %%
times
# Out:
# array([ 474.83078866,  546.52332125, 1236.87835705, 1331.29124515,
#         476.05086675,  432.98443989,  401.4120904 ,  387.42283511,
#         490.48272045,  752.59679313,  470.77712259])

# %%
flattened_samples, _, _ = my_UVLF.get_fit()

# %%
n_samples = len(flattened_samples)/times

# %%
all_data = np.hstack((np.round(times,0).reshape(-1,1), np.round(n_samples,0).reshape(-1,1)))

# %%
df = pd.DataFrame(data = all_data, columns = ['Autocorrelation time', '# of independent samples'], 
             index = ['alpha', 'dalphadz', 'beta', 'dbetadz', 'logMc', 'dlogMcdz', 'loge',
       'dlogedz', 'sig', 'dsigdz', 'dsigdlogM'], dtype = int, )

# %%
df
# Out:
#            Autocorrelation time  # of independent samples
# alpha                       475                      4619
# dalphadz                    547                      4013
# beta                       1237                      1773
# dbetadz                    1331                      1648
# logMc                       476                      4607
# dlogMcdz                    433                      5066
# loge                        401                      5464
# dlogedz                     387                      5662
# sig                         490                      4472
# dsigdz                      753                      2914
# dsigdlogM                   471                      4659

# %%
importlib.reload(eplots)
# Out:
# <module 'escripts.eplots' from '/Users/eb35267/Desktop/code/home/escripts/eplots.py'>

# %%
corner = eplots.make_corner(my_UVLF)

# %%
# # Purpose: plotting tools
# # Author: Emily Bregou

# # Standard packages
# import matplotlib as mpl
# from matplotlib import pyplot as plt
# import matplotlib.ticker as ticker
# from matplotlib import colors
# from matplotlib.legend_handler import HandlerLine2D
# from matplotlib.lines import Line2D
# import numpy as np
# import corner
# import math
# from matplotlib.gridspec import GridSpec

# # Local packages
# from escripts import estats
# from escripts import eMCMC
# from escripts import edata

# color_cycler = mpl.rcParams['axes.prop_cycle']
# colors = [c['color'] for c in color_cycler]
# hex_colors = [mpl.colors.to_hex(color) for color in colors]
# red = hex_colors[0]
# turquoise = hex_colors[1]
# yellow = hex_colors[2]
# navy = hex_colors[3]
# orange = hex_colors[4]
# green = hex_colors[5]
# periwinkle = hex_colors[6]
# labels = ['red', 'turquoise', 'yellow', 'navy', 'orange', 'green', 'periwinkle']


# def evolving_UVLF_fit(my_UVLF, z_plot = None, plot_samples = True, nsamples = 100, comparison_fits = [], comparison_labels = [], 
#                            title = 'UVLF data vs. MCMC fit'):
#     """
#     Plot the UVLF at different redshifts
#     Inputs:
#         my_UVLF: eMCMC UVLF object
#         z_plot [list of floats]: redshifts to plot, or leave as None if you want to plot all of them
#         plot_samples [bool]: whether or not to plot the best fit and samples from my_UVLF. If False, only comparison_fits parameter values
#                              will be plotted (so you can quickly check different fits this way).
#         nsamples [int]: number of samples from the MCMC chain you want to appear in addition to the best fit
#         comparison_fits [list of lists]: lists of parameter values that will be used to create comparison UVLFs
#         comparison_labels [list of strs]: labels that correspond to the parameter values in comparison_fits, for the legend
#         title [str]: overarching title of the plot
#     Outputs:
#         Figure showing the UVLF at different redshfits
#     """
#     data_z = [dat[0] for dat in my_UVLF.data] # Get the redshifts that correspond to the input data
    
#     if z_plot is None: # Plot every redshift if none are specified.
#         z_plot = data_z

#     assert all([z in data_z for z in z_plot]), 'The redshifts specified don\'t match the redshifts of the data'

#     # Figure out how many subplots to make
#     nz = len(z_plot)
#     fig, ax = plt.subplots(math.ceil(nz/3), 3, sharey = True, sharex=True)
    
#     if nz == 1:
#         ax = [ax]  # Make ax iterable even if it's just one subplot
#     fig.set_size_inches(2.5*math.ceil(nz/3), 1.25*nz)
#     plt.subplots_adjust(wspace = 0.05)

#     # Get samples & best fit
#     samples, best_fit, _ = my_UVLF.get_fit(exclude_unfit = True)
#     chi2 = -2 * my_UVLF.log_like(best_fit)
#     chi2_comparison = [-2*my_UVLF.log_like(fit) for fit in comparison_fits]

#     # Set the same y limits for all the plots
#     ylo, yhi = np.log10(min([min(dat[3]) for dat in my_UVLF.data]))-0.25, np.log10(max([max(dat[3]) for dat in my_UVLF.data]))+0.25 

#     plot_xdat, plot_xerr = my_UVLF.data[0][2], my_UVLF.data[0][5] # Use the lowest redshift MUV centers & bins as the grid to calculate the
#                                                                 # theoretical UVLF on
    
#     i = 0 # Tracks which axis you're on
#     for zbin in my_UVLF.sorted_data:

#         # Choose random samples from the MCMC chain
#         inds = np.random.randint(len(samples), size=nsamples) # Choose nsamples from the chain
    
#         zdat, zerr = zbin[0][0], zbin[0][1]

#         if zdat not in z_plot:
#             print(f'Skipping $z={zdat}$')
#             continue

#         if plot_samples:
#             # Plot each sample from the chain
#             for ind in inds: 
#                 sample = samples[ind]
#                 ax[math.floor(i/3), i%3].plot(plot_xdat, np.log10(my_UVLF.UVLF_wrapper(zdat,zerr,plot_xdat, plot_xerr,sample)), alpha=6/max(nsamples, 6), 
#                            color = red, linestyle = '-', zorder = 0)
    
#             # Plot best fit
#             chi2 = -2* my_UVLF.log_like(best_fit)
#             ax[math.floor(i/3), i%3].plot(plot_xdat, np.log10(my_UVLF.UVLF_wrapper(zdat, zerr, plot_xdat, plot_xerr, best_fit)), color = red, linestyle = '-', 
#                                            zorder = 0, label = f'best fit, $\chi^2 = {chi2:.0f}$')
            
#             ax[math.floor(i/3), i%3].plot([0], [0], color = red, alpha = 0.5, label = 'sampled fits', linestyle = '-') # Create the label for the samples
        
#         # Plot comparison fits
#         for fit, chi2_fit, label, color, ls in zip(comparison_fits, chi2_comparison, comparison_labels, [turquoise, yellow, orange, green], 
#                                         ['solid', 'dashdot', 'dashed', 'dotted']):
#             ax[math.floor(i/3), i%3].plot(plot_xdat, np.log10(my_UVLF.UVLF_wrapper(zdat,zerr,plot_xdat,plot_xerr, fit)), color = color, 
#                        label = f'{label}, $\chi^2 = {chi2_fit:.0f}$', linestyle = ls, zorder = 1)

#         # Plot data
#         for dat, fmt in zip(zbin, ['o', 'v', 's']):
#             _, _, xdat, ydat, yerr_upper, yerr_lower, xerr = edata.decompose(dat)
#             yerr_lower, yerr_upper = estats.calc_log_error(ydat, yerr_lower), estats.calc_log_error(ydat, yerr_upper)
#             ax[math.floor(i/3), i%3].errorbar(xdat, np.log10(ydat), [yerr_lower, yerr_upper], fmt = fmt, capsize=0, markersize = 9, label = dat[7], 
#                            markeredgecolor = 'none', markerfacecolor = navy, ecolor = navy)

#         i+=1 # Move to the next axis

#     for ax_i in np.concatenate(ax):
#         ax_i.invert_xaxis()
#         ax_i.set_ylim(ylo, yhi)
#         ax_i.set_xlim(np.max(plot_xdat)+0.25, np.min(plot_xdat)-0.25)
#         ax_i.set_title(f'$z \simeq {round(zdat, 1)}$')
#         ax_i.xaxis.set_major_locator(ticker.MaxNLocator(integer=True)) # Make it so that only integers can be used in the  
#                                                                                        # axis labels
        
#     fig.text(0.05, .5, r'$\log_{10}(\phi_{\rm{UV}}$ [$\rm{mag}^{-1} \rm{Mpc}^{-3}$])', ha = 'center', rotation = 'vertical', fontsize = 18)
#     fig.text(.5, 0.075, r'$M_{\rm{UV}}$ [mag]', ha = 'center', fontsize = 18)
#     fig.text(.5, 0.925, title, ha = 'center', fontsize = 20)

#     # Put the legend outside the plots
#     ax[-1, -1].legend(bbox_to_anchor= (1, 1))
    
#     return fig
# Out:
# <>:97: SyntaxWarning: invalid escape sequence '\c'
# <>:105: SyntaxWarning: invalid escape sequence '\c'
# <>:120: SyntaxWarning: invalid escape sequence '\s'
# <>:97: SyntaxWarning: invalid escape sequence '\c'
# <>:105: SyntaxWarning: invalid escape sequence '\c'
# <>:120: SyntaxWarning: invalid escape sequence '\s'
# /var/folders/mm/m_9lg4t966qdjwf1r__0773r0000gq/T/ipykernel_56188/3511669067.py:97: SyntaxWarning: invalid escape sequence '\c'
#   zorder = 0, label = f'best fit, $\chi^2 = {chi2:.0f}$')
# /var/folders/mm/m_9lg4t966qdjwf1r__0773r0000gq/T/ipykernel_56188/3511669067.py:105: SyntaxWarning: invalid escape sequence '\c'
#   label = f'{label}, $\chi^2 = {chi2_fit:.0f}$', linestyle = ls, zorder = 1)
# /var/folders/mm/m_9lg4t966qdjwf1r__0773r0000gq/T/ipykernel_56188/3511669067.py:120: SyntaxWarning: invalid escape sequence '\s'
#   ax_i.set_title(f'$z \simeq {round(zdat, 1)}$')

# %%
corner.savefig('/Users/eb35267/Desktop/code/figures/corner.png', bbox_inches = 'tight')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[244], line 1
# ----> 1 corner.savefig('/Users/eb35267/Desktop/code/figures/corner.png', bbox_inches = 'tight')
#
# AttributeError: module 'corner' has no attribute 'savefig'

# %%
# Purpose: plotting tools
# Author: Emily Bregou

# Standard packages
import matplotlib as mpl
from matplotlib import pyplot as plt
import matplotlib.ticker as ticker
from matplotlib import colors
from matplotlib.legend_handler import HandlerLine2D
from matplotlib.lines import Line2D
import numpy as np
import corner
import math
from matplotlib.gridspec import GridSpec

# Local packages
from escripts import estats
from escripts import eMCMC
from escripts import edata

color_cycler = mpl.rcParams['axes.prop_cycle']
colors = [c['color'] for c in color_cycler]
hex_colors = [mpl.colors.to_hex(color) for color in colors]
red = hex_colors[0]
turquoise = hex_colors[1]
yellow = hex_colors[2]
navy = hex_colors[3]
orange = hex_colors[4]
green = hex_colors[5]
periwinkle = hex_colors[6]
labels = ['red', 'turquoise', 'yellow', 'navy', 'orange', 'green', 'periwinkle']


def evolving_UVLF_fit(my_UVLF, z_plot = None, plot_from_chain = True, nsamples = 100, comparison_fits = [], comparison_labels = [], 
                           title = 'UVLF data vs. MCMC fit'):
    """
    Plot the UVLF at different redshifts
    Inputs:
        my_UVLF: eMCMC UVLF object
        z_plot [list of floats]: redshifts to plot, or leave as None if you want to plot all of them
        plot_from_chain [bool]: whether or not to plot the best fit and samples from the chain stored in my_UVLF. If False, only comparison_fits
                             parameter values will be plotted (so you can quickly check different fits this way).
        nsamples [int]: number of samples from the MCMC chain you want to appear in addition to the best fit
        comparison_fits [list of lists]: lists of parameter values that will be used to create comparison UVLFs
        comparison_labels [list of strs]: labels that correspond to the parameter values in comparison_fits, for the legend
        title [str]: overarching title of the plot
    Outputs:
        Figure showing the UVLF at different redshfits
    """
    data_z = [dat[0] for dat in my_UVLF.data] # Get the redshifts that correspond to the input data
    
    if z_plot is None: # Plot every redshift if none are specified.
        z_plot = data_z

    assert all([z in data_z for z in z_plot]), 'The redshifts specified don\'t match the redshifts of the data'

    # Figure out how many subplots to make
    nz = len(z_plot)
    fig, ax = plt.subplots(sharey=True, sharex=True)
    gs = GridSpec(math.ceil(nz/3), 3, figure=fig)
    
    # Adjust size & spacing
    fig.set_size_inches(2.5*math.ceil(nz/3), 1.25*nz)
    plt.subplots_adjust(wspace = 0, hspace = 0.4)

    # Get samples & best fit
    if plot_from_chain:
        samples, best_fit, _ = my_UVLF.get_fit(exclude_unfit = True)
        chi2 = -2 * my_UVLF.log_like(best_fit)
    
    chi2_comparison = [-2*my_UVLF.log_like(fit) for fit in comparison_fits]

    # Set the same y limits for all the plots
    ylo, yhi = np.log10(min([min(dat[3]) for dat in my_UVLF.data]))-0.25, np.log10(max([max(dat[3]) for dat in my_UVLF.data]))+0.25 

    # Get the x grid to evaluate the UVLF over
    plot_xdat, plot_xerr = my_UVLF.data[0][2], my_UVLF.data[0][5] # Use the lowest redshift MUV centers & bins as the grid to calculate the
                                                                # theoretical UVLF on
    for i, zbin in enumerate(my_UVLF.sorted_data):

        ax = fig.add_subplot(gs[math.floor(i/3), i%3])
    
        zdat, zerr = zbin[0][0], zbin[0][1]

        if zdat not in z_plot:
            print(f'Skipping $z={zdat}$')
            continue

        if plot_from_chain:
            # Choose random samples from the MCMC chain
            inds = np.random.randint(len(samples), size=nsamples) # Choose nsamples from the chain

            # Plot each sample from the chain
            for ind in inds: 
                sample = samples[ind]
                ax.plot(plot_xdat, np.log10(my_UVLF.UVLF_wrapper(zdat,zerr,plot_xdat, plot_xerr,sample)), alpha=6/max(nsamples, 6), 
                           color = red, linestyle = '-', zorder = 0)
    
            # Plot best fit
            chi2 = -2* my_UVLF.log_like(best_fit)
            ax.plot(plot_xdat, np.log10(my_UVLF.UVLF_wrapper(zdat, zerr, plot_xdat, plot_xerr, best_fit)), color = red, linestyle = '-', 
                                           zorder = 0, label = f'best fit, $\chi^2 = {chi2:.0f}$')
            
            ax.plot([0], [0], color = red, alpha = 0.5, label = 'sampled fits', linestyle = '-') # Create the label for the samples
        
        # Plot comparison fits
        for fit, chi2_fit, label, color, ls in zip(comparison_fits, chi2_comparison, comparison_labels, [turquoise, yellow, orange, green], 
                                        ['solid', 'dashdot', 'dashed', 'dotted']):
            ax.plot(plot_xdat, np.log10(my_UVLF.UVLF_wrapper(zdat,zerr,plot_xdat,plot_xerr, fit)), color = color, 
                       label = f'{label}, $\chi^2 = {chi2_fit:.0f}$', linestyle = ls, zorder = 1)

        # Plot data
        for dat, fmt in zip(zbin, ['o', 'v', 's']):
            _, _, xdat, ydat, yerr_upper, yerr_lower, xerr = edata.decompose(dat)
            yerr_lower, yerr_upper = estats.calc_log_error(ydat, yerr_lower), estats.calc_log_error(ydat, yerr_upper)
            ax.errorbar(xdat, np.log10(ydat), [yerr_lower, yerr_upper], fmt = fmt, capsize=0, markersize = 9, label = dat[7], 
                           markeredgecolor = 'none', markerfacecolor = navy, ecolor = navy)

        ax.invert_xaxis()
        ax.set_ylim(ylo, yhi)
        ax.set_xlim(np.max(plot_xdat)+0.25, np.min(plot_xdat)-0.25)
        ax.set_title(f'$z \simeq {round(zdat, 1)}$')
        ax.xaxis.set_major_locator(ticker.MaxNLocator(integer=True)) # Make it so that only integers can be used in the  
                                                                                       # axis labels
        if i%3 != 0:
            ax.axes.yaxis.set_ticklabels([])
        
    fig.text(0.05, .5, r'$\log_{10}(\phi_{\rm{UV}}$ [$\rm{mag}^{-1} \rm{Mpc}^{-3}$])', ha = 'center', rotation = 'vertical', fontsize = 18)
    fig.text(.5, 0.075, r'$M_{\rm{UV}}$ [mag]', ha = 'center', fontsize = 18)
    fig.text(.5, 0.925, title, ha = 'center', fontsize = 20)

    # Put the legend outside the plots
    #ax[-1, -1].legend(bbox_to_anchor= (1, 1))
    
    return fig
# Out:
# <>:100: SyntaxWarning: invalid escape sequence '\c'
# <>:108: SyntaxWarning: invalid escape sequence '\c'
# <>:120: SyntaxWarning: invalid escape sequence '\s'
# <>:100: SyntaxWarning: invalid escape sequence '\c'
# <>:108: SyntaxWarning: invalid escape sequence '\c'
# <>:120: SyntaxWarning: invalid escape sequence '\s'
# /var/folders/mm/m_9lg4t966qdjwf1r__0773r0000gq/T/ipykernel_56188/4165247253.py:100: SyntaxWarning: invalid escape sequence '\c'
#   zorder = 0, label = f'best fit, $\chi^2 = {chi2:.0f}$')
# /var/folders/mm/m_9lg4t966qdjwf1r__0773r0000gq/T/ipykernel_56188/4165247253.py:108: SyntaxWarning: invalid escape sequence '\c'
#   label = f'{label}, $\chi^2 = {chi2_fit:.0f}$', linestyle = ls, zorder = 1)
# /var/folders/mm/m_9lg4t966qdjwf1r__0773r0000gq/T/ipykernel_56188/4165247253.py:120: SyntaxWarning: invalid escape sequence '\s'
#   ax.set_title(f'$z \simeq {round(zdat, 1)}$')

# %%
evolv = evolving_UVLF_fit(my_UVLF)
# Out:
# /Users/eb35267/Desktop/code/home/escripts/eMCMC.py:152: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   insert_vals = self.param_data['value'][self.notfit]
# /Users/eb35267/Desktop/code/home/escripts/eMCMC.py:153: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   else:
# /Users/eb35267/Desktop/code/home/escripts/eMCMC.py:152: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   insert_vals = self.param_data['value'][self.notfit]
# /Users/eb35267/Desktop/code/home/escripts/eMCMC.py:153: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   else:
# /Users/eb35267/Desktop/code/home/escripts/eMCMC.py:152: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   insert_vals = self.param_data['value'][self.notfit]
# /Users/eb35267/Desktop/code/home/escripts/eMCMC.py:153: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   else:
# /Users/eb35267/Desktop/code/home/escripts/eMCMC.py:152: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   insert_vals = self.param_data['value'][self.notfit]
# /Users/eb35267/Desktop/code/home/escripts/eMCMC.py:153: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   else:
# /Users/eb35267/Desktop/code/home/escripts/eMCMC.py:152: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   insert_vals = self.param_data['value'][self.notfit]
# /Users/eb35267/Desktop/code/home/escripts/eMCMC.py:153: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   else:
# /Users/eb35267/Desktop/code/home/escripts/eMCMC.py:152: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   insert_vals = self.param_data['value'][self.notfit]
# /Users/eb35267/Desktop/code/home/escripts/eMCMC.py:153: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   else:
# /Users/eb35267/Desktop/code/home/escripts/eMCMC.py:152: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   insert_vals = self.param_data['value'][self.notfit]
# /Users/eb35267/Desktop/code/home/escripts/eMCMC.py:153: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   else:

# %%
#evolv.savefig('/Users/eb35267/Desktop/code/figures/evolving_fit.png', bbox_inches = 'tight')

# %%
eMCMC.make_table([bf], [labels], ['best fit'])
# Out:
#                                   best fit
# $\alpha$                              0.58
# $d\alpha/dz$                         -0.04
# $\beta$                              -0.12
# $d\beta/dz$                           0.13
# $\log(M_c)$                          12.02
# $d\log(M_c)/dz$                       0.09
# $\log(\epsilon_0)$                   -0.99
# $d\log(\epsilon_0)/dz$               -0.05
# $\sigma_{\rm{UV}, 10}$                0.04
# $d\sigma_{\rm{UV}}/dz$                0.49
# $d\sigma_{\rm{UV}}/d\log(M_{h})$      0.25
